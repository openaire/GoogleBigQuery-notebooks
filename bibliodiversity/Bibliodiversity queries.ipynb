# %% [markdown]
# ## Language diversity across research products

# %%
# %%bigquery
# WITH products as (
#   SELECT id, languageCode FROM oag_v10_6_0.publications
#   UNION ALL
#   SELECT id, languageCode FROM oag_v10_6_0.others
#   UNION ALL
#   SELECT id, languageCode FROM oag_v10_6_0.datasets
#   UNION ALL
#   SELECT id, languageCode FROM oag_v10_6_0.software
# )
# SELECT languageCode, COUNT( DISTINCT id) AS productCount
# FROM products
#   WHERE languageCode != "und"
# GROUP BY languageCode
# ORDER BY productCount DESC
# LIMIT 50
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    languageCode  productCount
# 0           eng     145507994
# 1       deu/ger       7705987
# 2       fra/fre       5576199
# 3           rus       4003936
# 4           jpn       3767133
# 5           ita       2481035
# 6           por       2159956
# 7       esl/spa       2117211
# 8           spa       1572071
# 9           tur       1484138
# 10      dut/nld        837766
# 11          pol        740124
# 12          hrv        683710
# 13      ces/cze        617005
# 14          fin        601439
# 15          swe        580751
# 16          ind        571871
# 17          ukr        484476
# 18          dan        371571
# 19          ara        341773
# 20          cat        312372
# 21          slv        299051
# 22          nor        267493
# 23          lit        247035
# 24      fas/per        187539
# 25      chi/zho        167872
# 26      ron/rum        160235
# 27          lat        125412
# 28      ell/gre        123245
# 29      gre/ell        112195
# 30          hun         91827
# 31          srp         76708
# 32          kor         71297
# 33          uzb         42770
# 34      slk/slo         39798
# 35           ng         36563
# 36          lav         34116
# 37          est         34036
# 38          bul         33285
# 39          nob         32917
# 40          gaa         31345
# 41          bel         30400
# 42        pt_BR         18485
# 43        el_GR         17866
# 44          mul         17139
# 45      baq/eus         12720
# 46          per         12392
# 47          lao         11838
# 48         null         10465
# 49      may/msa         10014

# %% [markdown]
# ## Geographic presence of the most prominent languages

# %%
# %%bigquery
# WITH products as (
#   SELECT id, type, languageCode FROM oag_v10_6_0.publications
#   UNION ALL
#   SELECT id, type, languageCode FROM oag_v10_6_0.others
#   UNION ALL
#   SELECT id, type, languageCode FROM oag_v10_6_0.datasets
#   UNION ALL
#   SELECT id, type, languageCode FROM oag_v10_6_0.software
# ),
# country_rel AS (
# 	SELECT r.source, r.target, o.countryCode
# 	FROM oag_v10_6_0.relations r
# 	JOIN oag_v10_6_0.organizations o ON r.target = o.id
# 		WHERE r.relationName = 'hasAuthorInstitution'
# )
# SELECT p.languageCode, r.countryCode, COUNT(DISTINCT p.id) AS productCount
# 	FROM products p
# 	JOIN country_rel r ON p.id = r.source
# 	  WHERE p.languageCode != "und"
# 	GROUP BY languageCode, countryCode
# 	ORDER BY productCount DESC
# LIMIT 50
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    languageCode countryCode  productCount
# 0           eng          JP      27509147
# 1           eng          US      21578529
# 2           eng          CN       7435585
# 3           eng          GB       6741792
# 4           eng          DE       4819594
# 5           eng          IT       3585172
# 6           eng          FR       3076989
# 7           eng          CA       3072550
# 8           eng          IN       2597863
# 9           eng          AU       2531138
# 10          eng          NL       1993942
# 11          eng          ES       1941024
# 12          ita          IT       1800495
# 13      fra/fre          FR       1616016
# 14          eng        None       1587542
# 15          eng          KR       1535545
# 16      deu/ger          DE       1451219
# 17          eng          CH       1339136
# 18          eng          RU       1303474
# 19          eng          SE       1194798
# 20          eng          TR       1122110
# 21          eng          BR       1102520
# 22          eng          BE       1059457
# 23          eng          PL        906245
# 24          tur          TR        807963
# 25          eng          DK        785947
# 26          eng          IR        778735
# 27          eng          TW        766762
# 28          eng          FI        737173
# 29      esl/spa          ES        736982
# 30          rus          RU        702366
# 31          eng          AT        655852
# 32          eng          PK        642717
# 33          eng          IL        589025
# 34          eng          PT        586588
# 35          eng          NO        539561
# 36          ind          ID        529269
# 37          eng          ZA        512275
# 38          pol          PL        510867
# 39          eng          EG        491725
# 40          eng          IE        471013
# 41          rus          BY        459155
# 42          eng          MX        457958
# 43          eng          SG        449480
# 44          por          PT        435055
# 45          eng          SA        434363
# 46          eng          GR        433518
# 47          eng          CZ        432419
# 48      dut/nld          NL        404283
# 49      ces/cze          CZ        388655

# %% [markdown]
# ## Top-level research product formats

# %%
# %%bigquery
# WITH products as (
#   SELECT id, type FROM oag_v10_6_0.publications
#   UNION ALL
#   SELECT id, type FROM oag_v10_6_0.others
#   UNION ALL
#   SELECT id, type FROM oag_v10_6_0.datasets
#   UNION ALL
#   SELECT id, type FROM oag_v10_6_0.software
# )
# SELECT type, COUNT(DISTINCT id) AS productCount
# FROM products
#
# GROUP BY type
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#           type  productCount
# 0        other      31628153
# 1  publication     205841448
# 2     software        737936
# 3      dataset      86236354

# %% [markdown]
# ## Share of top-level research product formats across languages

# %%
# %%bigquery
# WITH products as (
#   SELECT id, type, languageCode FROM oag_v10_6_0.publications
#   UNION ALL
#   SELECT id, type, languageCode FROM oag_v10_6_0.others
#   UNION ALL
#   SELECT id, type, languageCode FROM oag_v10_6_0.datasets
#   UNION ALL
#   SELECT id, type, languageCode FROM oag_v10_6_0.software
# )
# SELECT type, languageCode, COUNT(DISTINCT id) AS productCount
# FROM products
# where languageCode != "und"
# GROUP BY type, languageCode
# ORDER BY productCount desc
# LIMIT 50
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#            type languageCode  productCount
# 0   publication          eng     107899304
# 1       dataset          eng      32014668
# 2   publication      deu/ger       6021551
# 3         other          eng       5554670
# 4   publication      fra/fre       4222014
# 5   publication          rus       3523467
# 6   publication          jpn       3109349
# 7   publication          ita       2091194
# 8   publication      esl/spa       1684065
# 9   publication          tur       1424785
# 10        other      deu/ger       1162741
# 11        other      fra/fre       1149629
# 12  publication          por       1099832
# 13  publication          spa       1078590
# 14        other          por       1053906
# 15  publication          pol        693910
# 16  publication      dut/nld        693536
# 17  publication          hrv        618446
# 18        other          jpn        548700
# 19      dataset      deu/ger        521431
# 20  publication      ces/cze        503322
# 21        other          spa        492623
# 22        other          rus        474320
# 23        other          ind        444729
# 24  publication          ukr        390722
# 25        other          swe        355808
# 26        other      esl/spa        351683
# 27  publication          ara        325128
# 28  publication          fin        317141
# 29        other          fin        280882
# 30  publication          cat        251760
# 31  publication          nor        247505
# 32  publication          slv        246845
# 33  publication          swe        210691
# 34      dataset          ita        205167
# 35      dataset      fra/fre        204130
# 36  publication          dan        203756
# 37  publication      fas/per        184769
# 38        other          ita        183655
# 39  publication      ron/rum        158041
# 40        other          lit        157075
# 41  publication      chi/zho        156113
# 42      dataset          dan        131024
# 43  publication          ind        125865
# 44        other      ces/cze        112353
# 45      dataset          jpn        109080
# 46  publication      gre/ell        108972
# 47  publication          lat        102296
# 48  publication      ell/gre        100731
# 49  publication          lit         89786

# %% [markdown]
# ## Fine-grained bibliotyping of research products

# %%
# %%bigquery
# WITH products as (
#   SELECT id, type, instances FROM oag_v10_6_0.publications
#   UNION ALL
#   SELECT id, type, instances FROM oag_v10_6_0.others
#   UNION ALL
#   SELECT id, type, instances FROM oag_v10_6_0.datasets
#   UNION ALL
#   SELECT id, type, instances FROM oag_v10_6_0.software
# )
# SELECT  JSON_VALUE(inst, "$.type") AS fineGrainedType, COUNT(DISTINCT id) AS productCount
# FROM products,
# 	UNNEST(JSON_EXTRACT_ARRAY(instances)) AS inst
# GROUP BY fineGrainedType
# ORDER BY productCount desc
# LIMIT 50
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                                   fineGrainedType  productCount
# 0                                         Article     152805251
# 1                                         Dataset      47660209
# 2                                       Bioentity      37872442
# 3                           Other literature type      34723597
# 4                 Part of book or chapter of book      25750628
# 5                                  PhysicalObject      14055154
# 6                                  Other ORP type       7909218
# 7                                           Image       5923136
# 8                               Conference object       5919270
# 9                                            Book       4264106
# 10                                       Preprint       3822056
# 11                                        UNKNOWN       3016634
# 12                                Doctoral thesis       2676119
# 13                                  Master thesis       2505807
# 14                                         Thesis       2196727
# 15                                         Report       2077298
# 16                                         Review       1819700
# 17                                Bachelor thesis       1277063
# 18                                       Software        737936
# 19                                       Research        692842
# 20                                     Collection        655340
# 21                                   Presentation        389760
# 22                                    Audiovisual        277569
# 23                       External research report        262615
# 24                            Project deliverable        235861
# 25  Contribution for newspaper or weekly magazine        233475
# 26                                Research Object        213902
# 27                                        Journal        163259
# 28                                 Clinical Trial        150176
# 29                            InteractiveResource        126162
# 30                                          Sound         78852
# 31                                          Event         75504
# 32                                         Patent         72150
# 33                                        Lecture         70622
# 34                                     Annotation         38107
# 35                                           Film         33078
# 36                              Research Activity         31101
# 37                                          Model         25304
# 38                                     Data Paper         21413
# 39                           Data Management Plan         16247
# 40                                     Newsletter          7271
# 41                             Other dataset type          5961
# 42                               Project proposal          2588
# 43                              Project milestone          1462
# 44                                Internal report           717
# 45                                 Software Paper           239

# %% [markdown]
# ## Geographic coverage of research products

# %%
# %%bigquery
# WITH products as (
#   SELECT id, type FROM oag_v10_6_0.publications
#   UNION ALL
#   SELECT id, type FROM oag_v10_6_0.others
#   UNION ALL
#   SELECT id, type FROM oag_v10_6_0.datasets
#   UNION ALL
#   SELECT id, type FROM oag_v10_6_0.software
# ),
# country_rel AS (
# 	SELECT r.source, r.target, o.countryCode
# 	FROM oag_v10_6_0.relations r
# 	JOIN oag_v10_6_0.organizations o ON r.target = o.id
# 		WHERE r.relationName = 'hasAuthorInstitution'
# )
# SELECT r.countryCode, count(distinct p.id) AS productCount
# FROM products p
# JOIN country_rel r ON p.id = r.source
#
# GROUP BY countryCode
# ORDER BY productCount desc
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     countryCode  productCount
# 0            US      28921138
# 1            JP      28842106
# 2            CN      11279084
# 3            GB       8828750
# 4            DE       8267133
# ..          ...           ...
# 228          OC            13
# 229          AN             9
# 230          CK             6
# 231          KI             4
# 232          EH             3
#
# [233 rows x 2 columns]

# %% [markdown]
# ## Geographic coverage of organisations

# %%
# %%bigquery
# SELECT countryCode, COUNT(DISTINCT ID) AS organisationCount
# FROM oag_v10_6_0.organizations
# 	WHERE countryCode IS NOT NULL
#
# GROUP BY countryCode
# ORDER BY organisatiONCount DESC
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     countryCode  organisationCount
# 0            US              60667
# 1            FR              29349
# 2            GB              21532
# 3            DE              19926
# 4            IT              14330
# ..          ...                ...
# 235          TF                  1
# 236          NF                  1
# 237          PM                  1
# 238          UM                  1
# 239          YU                  1
#
# [240 rows x 2 columns]

# %% [markdown]
# ## Number of organisations across organisation types

# %%
# %%bigquery
# WITH organizations AS (
#     SELECT o.id, org.organizationtype
#     FROM oag_v10_6_0.organizations o
#     JOIN `oag_v10_6_0_additional.organization-types` org ON o.id = org.id
# )
# SELECT organizationtype, COUNT(DISTINCT id) AS nOrganisation
# FROM organizations
#   WHERE organizationtype != "Unknown"
# GROUP BY organizationtype
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#   organizationtype  nOrganisation
# 0        Education          20100
# 1        Nonprofit          12605
# 2       Government           5795
# 3       Healthcare          12478
# 4          Company          28018
# 5            Other           7820
# 6         Facility           8545
# 7          Archive           2736

# %% [markdown]
# ## Share of top-level research product formats across organisation types

# %%
# %%bigquery
# WITH products as (
#   SELECT id, type FROM oag_v10_6_0.publications
#   UNION ALL
#   SELECT id, type FROM oag_v10_6_0.others
#   UNION ALL
#   SELECT id, type FROM oag_v10_6_0.datasets
#   UNION ALL
#   SELECT id, type FROM oag_v10_6_0.software
# ),
# organizations AS (
# 	SELECT o.id, org.organizationtype
# 	FROM oag_v10_6_0.organizations o
# 	JOIN `oag_v10_6_0_additional.organization-types` org ON o.id = org.id
# )
# SELECT o.organizationtype, p.type, COUNT(DISTINCT p.id) AS productCount
# FROM oag_v10_6_0.relations r
# JOIN products p ON r.source = p.id
# JOIN organizations o ON r.target = o.id
# 	WHERE r.relationName = 'hasAuthorInstitution' AND o.organizationtype != "Unknown"
#
# GROUP BY o.organizationtype, p.type
# ORDER BY productCount DESC
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    organizationtype         type  productCount
# 0         Education  publication      93468440
# 1          Facility      dataset      23743701
# 2        Healthcare  publication      13794993
# 3        Government  publication      12907453
# 4          Facility  publication      11768627
# 5         Education        other       3613732
# 6         Nonprofit  publication       3429508
# 7           Company  publication       2498021
# 8         Education      dataset       1969294
# 9             Other  publication       1713224
# 10          Archive  publication       1069949
# 11         Facility        other        953647
# 12       Government      dataset        683391
# 13       Government        other        362640
# 14            Other        other        126655
# 15        Education     software        123451
# 16          Archive        other        111320
# 17       Healthcare      dataset        109312
# 18        Nonprofit      dataset         84148
# 19            Other      dataset         34241
# 20       Healthcare        other         33294
# 21         Facility     software         28897
# 22          Company      dataset         26501
# 23        Nonprofit        other         23362
# 24       Government     software         18238
# 25          Archive      dataset         16830
# 26        Nonprofit     software          8983
# 27          Company        other          5614
# 28       Healthcare     software          5354
# 29          Company     software          3447
# 30            Other     software          2608
# 31          Archive     software          1602

# %% [markdown]
# ## Number of research products per top-level format across Fields of Science

# %%
# %%bigquery
# WITH products as (
#   SELECT id, type, subjects FROM oag_v10_6_0.publications
#   UNION ALL
#   SELECT id, type, subjects FROM oag_v10_6_0.others
#   UNION ALL
#   SELECT id, type, subjects FROM oag_v10_6_0.datasets
#   UNION ALL
#   SELECT id, type, subjects FROM oag_v10_6_0.software
# )
# SELECT JSON_VALUE(subject.subject.value) AS fos, type, COUNT(DISTINCT id) AS nProducts
# FROM products,
# 	UNNEST(JSON_EXTRACT_ARRAY(subjects)) AS subject
# 	WHERE JSON_VALUE(subject.subject.scheme) = "FOS"
#
# GROUP BY fos, type
# ORDER BY fos, type ASC
# LIMIT 50
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                                                   fos         type  nProducts
# 0                                 01 natural sciences      dataset       1509
# 1                                 01 natural sciences        other       5520
# 2                                 01 natural sciences  publication   23039157
# 3                                 01 natural sciences     software          4
# 4                                    0101 mathematics      dataset          9
# 5                                    0101 mathematics        other        760
# 6                                    0101 mathematics  publication    2536226
# 7                                    0101 mathematics     software          4
# 8              0102 computer and information sciences      dataset          2
# 9              0102 computer and information sciences        other        114
# 10             0102 computer and information sciences  publication     459826
# 11                             0103 physical sciences      dataset          6
# 12                             0103 physical sciences        other       1000
# 13                             0103 physical sciences  publication    8126653
# 14                             0104 chemical sciences      dataset         32
# 15                             0104 chemical sciences        other        784
# 16                             0104 chemical sciences  publication    6506250
# 17      0105 earth and related environmental sciences      dataset         49
# 18      0105 earth and related environmental sciences        other       1510
# 19      0105 earth and related environmental sciences  publication    4361065
# 20                           0106 biological sciences      dataset       1462
# 21                           0106 biological sciences        other       1776
# 22                           0106 biological sciences  publication    2876409
# 23                      02 engineering and technology      dataset         38
# 24                      02 engineering and technology        other       4809
# 25                      02 engineering and technology  publication   19356588
# 26                             0201 civil engineering        other        170
# 27                             0201 civil engineering  publication     486803
# 28  0202 electrical engineering, electronic engine...      dataset         15
# 29  0202 electrical engineering, electronic engine...        other       2630
# 30  0202 electrical engineering, electronic engine...  publication    8123846
# 31                        0203 mechanical engineering        other        220
# 32                        0203 mechanical engineering  publication    1458159
# 33                          0204 chemical engineering      dataset          1
# 34                          0204 chemical engineering        other         79
# 35                          0204 chemical engineering  publication     511828
# 36                         0205 materials engineering        other         62
# 37                         0205 materials engineering  publication     363546
# 38                           0206 medical engineering      dataset          1
# 39                           0206 medical engineering        other         41
# 40                           0206 medical engineering  publication     268498
# 41                     0207 environmental engineering      dataset          4
# 42                     0207 environmental engineering        other        158
# 43                     0207 environmental engineering  publication     528323
# 44                   0208 environmental biotechnology      dataset          2
# 45                   0208 environmental biotechnology        other         46
# 46                   0208 environmental biotechnology  publication     173436
# 47                      0209 industrial biotechnology      dataset          1
# 48                      0209 industrial biotechnology        other        279
# 49                      0209 industrial biotechnology  publication    1380534

# %% [markdown]
# ## Number of research products per top-level format across Sustainable Development Goals

# %%
# %%bigquery
# WITH products as (
#   SELECT id, type, subjects FROM oag_v10_6_0.publications
#   UNION ALL
#   SELECT id, type, subjects FROM oag_v10_6_0.others
#   UNION ALL
#   SELECT id, type, subjects FROM oag_v10_6_0.datasets
#   UNION ALL
#   SELECT id, type, subjects FROM oag_v10_6_0.software
# )
# SELECT JSON_VALUE(subject.subject.value) AS SDG, type, count(distinct id) AS nProducts
# FROM products,
# 	UNNEST(JSON_EXTRACT_ARRAY(subjects)) AS subject
#
# 	WHERE JSON_VALUE(subject.subject.scheme) = "SDG"
# GROUP BY SDG, type
# ORDER BY SDG, type ASC
# LIMIT 50
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                             SDG         type  nProducts
# 0                 1. No poverty      dataset      35642
# 1                 1. No poverty        other     121623
# 2                 1. No poverty  publication    2850669
# 3                 1. No poverty     software        326
# 4             10. No inequality      dataset      18864
# 5             10. No inequality        other      79191
# 6             10. No inequality  publication    2872257
# 7             10. No inequality     software        142
# 8            11. Sustainability      dataset      77396
# 9            11. Sustainability        other     134571
# 10           11. Sustainability  publication    3608330
# 11           11. Sustainability     software       1277
# 12  12. Responsible consumption      dataset      16175
# 13  12. Responsible consumption        other      78479
# 14  12. Responsible consumption  publication    2502704
# 15  12. Responsible consumption     software        287
# 16           13. Climate action      dataset     226970
# 17           13. Climate action        other     122323
# 18           13. Climate action  publication    6245487
# 19           13. Climate action     software       5770
# 20          14. Life underwater      dataset     421602
# 21          14. Life underwater        other     107729
# 22          14. Life underwater  publication    2227575
# 23          14. Life underwater     software       3786
# 24             15. Life on land      dataset    1450538
# 25             15. Life on land        other     415714
# 26             15. Life on land  publication    3955266
# 27             15. Life on land     software       5475
# 28          16. Peace & justice      dataset     129036
# 29          16. Peace & justice        other     190317
# 30          16. Peace & justice  publication    5209907
# 31          16. Peace & justice     software        761
# 32               2. Zero hunger      dataset      92849
# 33               2. Zero hunger        other     135800
# 34               2. Zero hunger  publication    5572366
# 35               2. Zero hunger     software       1350
# 36               3. Good health      dataset     555135
# 37               3. Good health        other     379513
# 38               3. Good health  publication   26349544
# 39               3. Good health     software      11179
# 40                 4. Education      dataset      57284
# 41                 4. Education        other     310395
# 42                 4. Education  publication    5123576
# 43                 4. Education     software       1020
# 44           5. Gender equality      dataset      13283
# 45           5. Gender equality        other      43926
# 46           5. Gender equality  publication    1285271
# 47           5. Gender equality     software        148
# 48               6. Clean water      dataset     130141
# 49               6. Clean water        other      76713

# %% [markdown]
# ## Share of research products per Sustainable Development Goals across countries

# %%
# %%bigquery
# WITH products as (
#   SELECT id, type, subjects FROM oag_v10_6_0.publications
#   UNION ALL
#   SELECT id, type, subjects FROM oag_v10_6_0.others
#   UNION ALL
#   SELECT id, type, subjects FROM oag_v10_6_0.datasets
#   UNION ALL
#   SELECT id, type, subjects FROM oag_v10_6_0.software
# ),
# country_rel AS (
# 	SELECT r.source, r.target, o.countryCode
# 	FROM oag_v10_6_0.relations r
# 	JOIN oag_v10_6_0.organizations o ON r.target = o.id
# 	WHERE r.relationName = 'hasAuthorInstitution'
# )
# SELECT JSON_VALUE(subject.subject.value) AS SDG, r.countryCode, count(distinct id) AS nProducts
# FROM products p,
# UNNEST(JSON_EXTRACT_ARRAY(subjects)) AS subject
# JOIN country_rel r ON p.id = r.source
# WHERE JSON_VALUE(subject.subject.scheme) = "SDG"
# GROUP BY SDG, r.countryCode
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                       SDG countryCode  nProducts
# 0          6. Clean water          NL      58446
# 1          2. Zero hunger          SY       3424
# 2      11. Sustainability          IN     119746
# 3     14. Life underwater          FR     112556
# 4      5. Gender equality          NG      11415
# ...                   ...         ...        ...
# 3602  16. Peace & justice          BI        173
# 3603         4. Education          NC         93
# 3604   5. Gender equality          MN        243
# 3605   8. Economic growth          GQ          1
# 3606   8. Economic growth          MS          6
#
# [3607 rows x 3 columns]

# %% [markdown]
# ## Data providers collected by the OpenAIRE Graph

# %%
# %%bigquery
# SELECT distinct type, count(distinct id) AS dataSourcesCount
# FROM oag_v10_6_0.datasources
# GROUP BY type
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                                    type  dataSourcesCount
# 0                               Journal            143313
# 1                               service               631
# 2                     Instiutional CRIS              1335
# 3                       Data Repository              4834
# 4          Journal Aggregator/Publisher               299
# 5                       Funder database               241
# 6              Institutional Repository              5825
# 7                   Thematic Repository               411
# 8                Publication Repository               205
# 9        National multidiscplinary CRIS                25
# 10        Registry of research products                 3
# 11                Publication Catalogue                20
# 12    Publication Repository Aggregator               114
# 13                  Software Repository                 2
# 14                          CRIS System                22
# 15                           Repository                 2
# 16  Institutional Repository Aggregator                29
# 17                                 None                16
# 18                      CRIS Aggregator                 2
# 19                        Regional CRIS                 7
# 20           Data Repository Aggregator                22
# 21             Registry of repositories                 5
# 22                          Funder CRIS                12
# 23       Software Repository Aggregator                 5
# 24                           Web Source                 1
# 25       Scholarly Comm. Infrastructure                 2
# 26                                Other                 4
# 27            Registry of organizations                 3
# 28                           aggregator                 1
# 29                             Registry                 1

# %% [markdown]
# ## Top-10 countries for managed journals

# %%
# %%bigquery
# with filtered_relations AS (
#   SELECT r.source, r.relationName, r.target
#   FROM oag_v10_6_0.datasources d
#   JOIN oag_v10_6_0.relations r ON d.id = r.source
#     WHERE r.relationName = 'isProvidedBy' and r.targetType = 'organization' and d.type = "Journal"
# )
# SELECT o.countryCode, count(distinct r.source) AS nJournals
# FROM filtered_relations r
# JOIN oag_v10_6_0.organizations o ON r.target = o.id
# WHERE o.countryCode IS NOT NULL
# GROUP BY o.countryCode
# ORDER BY nJournals DESC
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     countryCode  nJournals
# 0            ID       3189
# 1            GB       2809
# 2            BR       1750
# 3            US       1338
# 4            PL       1286
# ..          ...        ...
# 140          JM          1
# 141          TJ          1
# 142          AX          1
# 143          TT          1
# 144          BS          1
#
# [145 rows x 2 columns]

# %% [markdown]
# ## Access rights of research products over time

# %%
# %%bigquery
# SELECT EXTRACT(YEAR FROM DATE(publicationDate)) as year,
#       JSON_VALUE(bestAccessRight.label) AS OA_status,
#       COUNT(*) AS n_papers
# FROM oag_v10_6_0.publications
# GROUP BY year, OA_status
# HAVING year BETWEEN 2000 AND 2025
# ORDER BY year DESC
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      year   OA_status  n_papers
# 0    2025      CLOSED   1646809
# 1    2025        None   2761792
# 2    2025  RESTRICTED     42459
# 3    2025     EMBARGO     11996
# 4    2025        OPEN   3167674
# ..    ...         ...       ...
# 125  2000     EMBARGO       303
# 126  2000  RESTRICTED     27725
# 127  2000      CLOSED    861681
# 128  2000        OPEN    545675
# 129  2000        None    945185
#
# [130 rows x 3 columns]

# %% [markdown]
# ## Funders and respective amount of funded projects

# %%
# %%bigquery
# SELECT JSON_VALUE(funding, '$.shortName') AS funderId, JSON_VALUE(funding, '$.name') AS funderName, count(distinct id) AS nProjects
# FROM oag_v10_6_0.projects,
# 	UNNEST(JSON_QUERY_ARRAY(fundings)) AS funding
# GROUP BY funderId, funderName
# ORDER BY nProjects DESC
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#       funderId                                    funderName  nProjects
# 0          NIH                 National Institutes of Health    2274103
# 1          NSF                   National Science Foundation     592489
# 2         UKRI                    UK Research and Innovation     175092
# 3           EC                           European Commission     115447
# 4          FCT  Fundação para a Ciência e a Tecnologia, I.P.      94440
# ..         ...                                           ...        ...
# 209        EPA               Environmental Protection Agency          1
# 210                                 Simon Cumbers Media Fund          1
# 211  EDTECH-ID                       Teknologi Pendidikan ID          1
# 212                 Alimentary Glycoscience Research Cluster          1
# 213       CIHR        Canadian Institutes of Health Research          1
#
# [214 rows x 3 columns]

# %% [markdown]
# ## Geographic coverage of funders jurisdiction

# %%
# %%bigquery
# SELECT JSON_VALUE(funding.jurisdiction) AS fundingJurisdiction, COUNT(DISTINCT JSON_VALUE(funding.shortName)) AS nFunding
# FROM oag_v10_6_0.projects ,
# UNNEST (JSON_EXTRACT_ARRAY(fundings)) AS funding
# GROUP BY fundingJurisdiction
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    fundingJurisdiction  nFunding
# 0                   DK         6
# 1                   DE         1
# 2                   CH         1
# 3                   RS         1
# 4                   FI        19
# 5                   HR         2
# 6                   BS         1
# 7                   IE         6
# 8                   CA         3
# 9                   NL         1
# 10                  EU         3
# 11                  LV         1
# 12                  US         3
# 13                  TR         1
# 14                  AU         2
# 15                  FR         3
# 16                             1
# 17                  NO         1
# 18                  CY         1
# 19                  ID         1
# 20                  PT         1
# 21                  GB         1
# 22                  AT         1

# %% [markdown]
# ## Top-level research product format across funders

# %%
# %%bigquery
# WITH products as (
#   SELECT id, type, languageCode FROM oag_v10_6_0.publications
#   UNION ALL
#   SELECT id, type, languageCode FROM oag_v10_6_0.others
#   UNION ALL
#   SELECT id, type, languageCode FROM oag_v10_6_0.datasets
#   UNION ALL
#   SELECT id, type, languageCode FROM oag_v10_6_0.software
# ),
# enriched_products AS (
# 	SELECT r.source AS projectId, r.target AS productId, r.relatiONName, pr.fundings, p.type
# 	FROM oag_v10_6_0.relations r
# 	JOIN oag_v10_6_0.projects pr ON r.source = pr.id
# 	JOIN products p ON r.target = p.id
# 		WHERE r.relationName = 'produces'
# )
# SELECT JSON_VALUE(funder.shortName) AS funderId, JSON_VALUE(funder.name) AS funderName, type, COUNT(DISTINCT productId) AS nProduct
# FROM enriched_products ,
# 	UNNEST(JSON_EXTRACT_ARRAY(fundings)) AS funder
#
# GROUP BY funderId, funderName, type
# ORDER BY funderName ASC, nProduct DESC
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     funderId                                      funderName         type  \
# 0              ADAPT - Centre for Digital Content Technology  publication
# 1                                   APC Microbiome Institute  publication
# 2                                   APC Microbiome Institute      dataset
# 3             Advanced Materials and Bioengineering Research  publication
# 4       ASAP             Aligning Science Across Parkinson's  publication
# ..       ...                                             ...          ...
# 339       WT                                  Wellcome Trust  publication
# 340       WT                                  Wellcome Trust      dataset
# 341       WT                                  Wellcome Trust        other
# 342       WT                                  Wellcome Trust     software
# 343                                      X-Bolt Orthopaedics  publication
#
#      nProduct
# 0          60
# 1          23
# 2           7
# 3          35
# 4         101
# ..        ...
# 339    198557
# 340     52345
# 341      3755
# 342       355
# 343         1
#
# [344 rows x 4 columns]

# %% [markdown]
# ## Language diversity in research products across funders

# %%
# %%bigquery
# WITH products as (
#   SELECT id, type, languageCode FROM oag_v10_6_0.publications
#   UNION ALL
#   SELECT id, type, languageCode FROM oag_v10_6_0.others
#   UNION ALL
#   SELECT id, type, languageCode FROM oag_v10_6_0.datasets
#   UNION ALL
#   SELECT id, type, languageCode FROM oag_v10_6_0.software
# ),
# enriched_products AS (
# 	SELECT r.source AS projectId, r.target AS productId, r.relatiONName, pr.fundings, p.languageCode
# 	FROM oag_v10_6_0.relations r
# 	JOIN oag_v10_6_0.projects pr ON r.source = pr.id
# 	JOIN products p ON r.target = p.id
# 		WHERE r.relationName = 'produces'
# )
# SELECT JSON_VALUE(funding.shortName) AS funderId, JSON_VALUE(funding.name) AS funderName, count(distinct languageCode) AS languageCount, count(distinct productId) AS productsCount
# FROM enriched_products,
# 	UNNEST(JSON_QUERY_ARRAY(fundings)) AS funding
# GROUP BY funderId, funderName
# ORDER BY productsCount DESC
# LIMIT 50
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      funderId                                         funderName  \
# 0          EC                                European Commission
# 1         NIH                      National Institutes of Health
# 2        UKRI                         UK Research and Innovation
# 3         NSF                        National Science Foundation
# 4         DFG                    Deutsche Forschungsgemeinschaft
# 5       NSERC  Natural Sciences and Engineering Research Coun...
# 6          WT                                     Wellcome Trust
# 7         FCT       Fundação para a Ciência e a Tecnologia, I.P.
# 8        CIHR             Canadian Institutes of Health Research
# 9        SNSF                  Swiss National Science Foundation
# 10        ARC                  Australian Research Council (ARC)
# 11        ANR              French National Research Agency (ANR)
# 12      MESTD  Ministry of Education, Science and Technologic...
# 13      NHMRC  National Health and Medical Research Council (...
# 14        NWO  Netherlands Organisation for Scientific Resear...
# 15        FWF                        Austrian Science Fund (FWF)
# 16        AKA                        Research Council of Finland
# 17        RCN                     The Research Council of Norway
# 18      SSHRC    Social Sciences and Humanities Research Council
# 19        SFI                         Science Foundation Ireland
# 20        IRC                             Irish Research Council
# 21       HRZZ                  Croatian Science Foundation (CSF)
# 22        NNF                            Novo Nordisk Foundation
# 23    TUBITAK    Türkiye Bilimsel ve Teknolojik Araştırma Kurumu
# 24       IReL                            Irish Research eLibrary
# 25       MZOS  Ministry of Science, Education and Sports of t...
# 26       MZOS  Ministry of Science, Education and Youth of th...
# 27        HRB                              Health Research Board
# 28       IRFD                  Independent Research Fund Denmark
# 29       INCa                        Institut National du Cancer
# 30         CF                               Carlsberg Foundation
# 31  CHIST-ERA                                          CHIST-ERA
# 32             Department of Agriculture, Food and the Marine...
# 33       TARA                        Tara Expeditions Foundation
# 34                                     University College Dublin
# 35                                            Enterprise Ireland
# 36                                                      Allergan
# 37        RIF                 Research and Innovation Foundation
# 38        EPA                    Environmental Protection Agency
# 39                                        Trinity College Dublin
# 40                                          University of Galway
# 41                                    Higher Education Authority
# 42                                                       Teagasc
# 43                          Royal College of Surgeons in Ireland
# 44                                       University College Cork
# 45                                          Jazz Pharmaceuticals
# 46                                        University of Limerick
# 47                                          Irish Cancer Society
# 48                       Sustainable Energy Authority of Ireland
# 49                                        Dublin City University
#
#     languageCount  productsCount
# 0              86        1745368
# 1              38        1084736
# 2              62         877634
# 3              32         616594
# 4              24         359311
# 5              24         339999
# 6              43         255012
# 7              61         210862
# 8              21         154352
# 9              20         141129
# 10             18         128336
# 11             27         121091
# 12             36          78306
# 13             16          66246
# 14             30          59425
# 15             29          55396
# 16             13          53172
# 17             23          46094
# 18             18          43290
# 19             13          26957
# 20             13          15942
# 21             21          15532
# 22              3          14482
# 23             14          13255
# 24              4          11880
# 25             15          11171
# 26             15          11086
# 27              9          10825
# 28              3           8710
# 29              8           7600
# 30              2           5840
# 31              8           3804
# 32              2           2675
# 33              8           1692
# 34              2           1558
# 35              2           1483
# 36              4           1240
# 37              2            840
# 38              3            777
# 39              3            753
# 40              3            619
# 41              3            591
# 42              2            570
# 43              2            520
# 44              3            490
# 45              3            426
# 46              2            417
# 47              3            388
# 48              2            354
# 49              3            331

# %% [markdown]
# ## Number of research products per Sustainable Development Goals across Funders

# %%
# %%bigquery
# WITH products as (
#   SELECT id, type, subjects FROM oag_v10_6_0.publications
#   UNION ALL
#   SELECT id, type, subjects FROM oag_v10_6_0.others
#   UNION ALL
#   SELECT id, type, subjects FROM oag_v10_6_0.datasets
#   UNION ALL
#   SELECT id, type, subjects FROM oag_v10_6_0.software
# ),
# enriched_products AS (
# 	SELECT r.source AS projectId, r.target AS productId, r.relationName, pr.fundings, p.subjects
# 	FROM oag_v10_6_0.relations r
# 	JOIN oag_v10_6_0.projects pr ON r.source = pr.id
# 	JOIN products p ON r.target = p.id
# 		WHERE r.relationName = 'produces'
# )
# SELECT JSON_VALUE(funding, "$.shortName") AS funderId, JSON_VALUE(funding, "$.name") AS funderName, JSON_VALUE(subject.subject.value) AS SDG, count(distinct productId) AS n_products
# FROM enriched_products,
# 	UNNEST(JSON_QUERY_ARRAY(fundings)) AS funding,
# 	UNNEST(JSON_QUERY_ARRAY(subjects)) AS subject
#
# 	WHERE JSON_VALUE(subject.subject.scheme) = "SDG"
# GROUP BY funderId, funderName, SDG
# ORDER BY funderId, funderName, SDG ASC
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      funderId                                     funderName  \
# 0              ADAPT - Centre for Digital Content Technology
# 1              ADAPT - Centre for Digital Content Technology
# 2              ADAPT - Centre for Digital Content Technology
# 3              ADAPT - Centre for Digital Content Technology
# 4              ADAPT - Centre for Digital Content Technology
# ...       ...                                            ...
# 1495       WT                                 Wellcome Trust
# 1496       WT                                 Wellcome Trust
# 1497       WT                                 Wellcome Trust
# 1498       WT                                 Wellcome Trust
# 1499       WT                                 Wellcome Trust
#
#                                  SDG  n_products
# 0                 11. Sustainability           1
# 1                 13. Climate action           1
# 2                     3. Good health           6
# 3                       4. Education           1
# 4                    7. Clean energy           3
# ...                              ...         ...
# 1495              5. Gender equality        3170
# 1496                  6. Clean water        1981
# 1497                 7. Clean energy        2325
# 1498              8. Economic growth        1992
# 1499  9. Industry and infrastructure         850
#
# [1500 rows x 4 columns]
