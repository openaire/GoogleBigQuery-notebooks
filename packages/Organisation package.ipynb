# %% [markdown]
# OpenOrgID Uni. Minho `openorgs____::759d59f05d77188faee99b7493b46805`

# %% [markdown]
# # Overall

# %% [markdown]
# ## Publications

# %%
# %%bigquery
#
# SELECT EXTRACT(YEAR FROM DATE(publicationDate)) AS year,
#   COUNT(DISTINCT pub.id) AS total
# FROM oag_v9_0_1.publications AS pub,
#   oag_v9_0_1.relations AS rels
# WHERE pub.id = rels.source AND
#   rels.target = 'openorgs____::759d59f05d77188faee99b7493b46805'
# GROUP BY year
# HAVING year BETWEEN 2005 AND 2025
# ORDER BY year DESC
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     year  total
# 0   2025      3
# 1   2024   2760
# 2   2023   6398
# 3   2022   6991
# 4   2021   7071
# 5   2020   5989
# 6   2019   6728
# 7   2018   6380
# 8   2017   7032
# 9   2016   6247
# 10  2015   6284
# 11  2014   6137
# 12  2013   5938
# 13  2012   5950
# 14  2011   4949
# 15  2010   3310
# 16  2009   3005
# 17  2008   2588
# 18  2007   2233
# 19  2006   2010
# 20  2005   1721

# %%
# %%bigquery
#
# SELECT EXTRACT(YEAR FROM DATE(publicationDate)) AS year,
#   COUNT(DISTINCT pub.id) AS total
# FROM oag_v9_0_1.publications AS pub,
#   oag_v9_0_1.relations AS rels,
#   UNNEST(JSON_QUERY_ARRAY(pub.instances)) AS instance
# WHERE pub.id = rels.source AND
#   rels.target = 'openorgs____::759d59f05d77188faee99b7493b46805' AND
#   JSON_VALUE(instance.refereed) = 'peerReviewed'
# GROUP BY year
# HAVING year BETWEEN 2005 AND 2025
# ORDER BY year DESC
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     year  total
# 0   2025      3
# 1   2024   1582
# 2   2023   3326
# 3   2022   3623
# 4   2021   4172
# 5   2020   3731
# 6   2019   3377
# 7   2018   3091
# 8   2017   3162
# 9   2016   2902
# 10  2015   2641
# 11  2014   2385
# 12  2013   2237
# 13  2012   2059
# 14  2011   1604
# 15  2010   1384
# 16  2009   1175
# 17  2008   1021
# 18  2007    906
# 19  2006    785
# 20  2005    577

# %% [markdown]
# ## Datasets

# %%
# %%bigquery
#
# SELECT EXTRACT(YEAR FROM DATE(publicationDate)) AS year,
#   COUNT(DISTINCT dts.id) AS total
# FROM oag_v9_0_1.datasets AS dts,
#   oag_v9_0_1.relations AS rels
# WHERE dts.id = rels.source AND
#   rels.target = 'openorgs____::759d59f05d77188faee99b7493b46805'
# GROUP BY year
# HAVING year BETWEEN 2005 AND 2025
# ORDER BY year DESC
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     year  total
# 0   2024     13
# 1   2023     83
# 2   2022    114
# 3   2021     19
# 4   2020     21
# 5   2019      6
# 6   2018      7
# 7   2017      3
# 8   2016      3
# 9   2015      6
# 10  2014      6
# 11  2013      8
# 12  2012      3
# 13  2011      1
# 14  2010      6
# 15  2009      1
# 16  2008      1
# 17  2007      1

# %% [markdown]
# ## Subjects

# %%
# %%bigquery
#
# SELECT EXTRACT(YEAR FROM DATE(publicationDate)) AS year,
#   JSON_VALUE(subject.subject.value) AS fos,
#   COUNT(DISTINCT pub.id) AS total
# FROM oag_v9_0_1.publications AS pub,
#   oag_v9_0_1.relations AS rels,
#   UNNEST(JSON_QUERY_ARRAY(pub.subjects)) AS subject
# WHERE pub.id = rels.source
#   AND rels.target = 'openorgs____::759d59f05d77188faee99b7493b46805'
#   AND JSON_VALUE(subject.subject.scheme) = 'FOS'
#   AND REGEXP_CONTAINS(JSON_VALUE(subject.subject.value), r'^\d{2}\s.*')
# GROUP BY year, fos
# HAVING year BETWEEN 2005 AND 2025
# ORDER BY year DESC, fos ASC
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      year                                      fos  total
# 0    2024                      01 natural sciences      8
# 1    2024            02 engineering and technology      9
# 2    2024           03 medical and health sciences      3
# 3    2024                       05 social sciences      1
# 4    2023                      01 natural sciences    129
# ..    ...                                      ...    ...
# 143  2000            02 engineering and technology     74
# 144  2000           03 medical and health sciences     38
# 145  2000  04 agricultural and veterinary sciences      3
# 146  2000                       05 social sciences     30
# 147  2000               06 humanities and the arts      2
#
# [148 rows x 3 columns]

# %% [markdown]
# ## SDGs

# %%
# %%bigquery
#
# SELECT EXTRACT(YEAR FROM DATE(publicationDate)) AS year,
#   JSON_VALUE(subject.subject.value) AS sdg,
#   COUNT(DISTINCT pub.id) AS total
# FROM oag_v9_0_1.publications AS pub,
#   oag_v9_0_1.relations AS rels,
#   UNNEST(JSON_QUERY_ARRAY(pub.subjects)) AS subject
# WHERE pub.id = rels.source
#   AND rels.target = 'openorgs____::759d59f05d77188faee99b7493b46805'
#   AND JSON_VALUE(subject.subject.scheme) = 'SDG'
# GROUP BY year, sdg
# HAVING year BETWEEN 2005 AND 2025
# ORDER BY year DESC, sdg ASC
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      year                             sdg  total
# 0    2024               10. No inequality      2
# 1    2024              11. Sustainability      1
# 2    2024     12. Responsible consumption      3
# 3    2024              13. Climate action      2
# 4    2024                15. Life on land      1
# ..    ...                             ...    ...
# 306  2005              5. Gender equality      2
# 307  2005                  6. Clean water     23
# 308  2005                 7. Clean energy     15
# 309  2005              8. Economic growth      7
# 310  2005  9. Industry and infrastructure      1
#
# [311 rows x 3 columns]

# %%
# %%bigquery
#
# SELECT
#   JSON_VALUE(subject.subject.value) AS sdg,
#   COUNT(DISTINCT pub.id) AS total
# FROM oag_v9_0_1.publications AS pub,
#   oag_v9_0_1.relations AS rels,
#   UNNEST(JSON_QUERY_ARRAY(pub.subjects)) AS subject
# WHERE pub.id = rels.source
#   AND rels.target = 'openorgs____::759d59f05d77188faee99b7493b46805'
#   AND JSON_VALUE(subject.subject.scheme) = 'SDG'
# GROUP BY sdg
# ORDER BY sdg ASC
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                                sdg  total
# 0                    1. No poverty    358
# 1                10. No inequality    579
# 2               11. Sustainability   1823
# 3      12. Responsible consumption   1602
# 4               13. Climate action   1531
# 5              14. Life underwater    238
# 6                 15. Life on land    641
# 7              16. Peace & justice   1048
# 8                   2. Zero hunger    815
# 9                   3. Good health   3296
# 10                    4. Education   2629
# 11              5. Gender equality    267
# 12                  6. Clean water    914
# 13                 7. Clean energy   1398
# 14              8. Economic growth    918
# 15  9. Industry and infrastructure    491

# %% [markdown]
# # Projects

# %%
# %%bigquery
#
# SELECT JSON_VALUE(funding.name) AS funder, (DISTINCT proj.id) AS totalCOUNT
# FROM oag_v9_0_1.projects AS proj,
#   oag_v9_0_1.relations AS rel,
#   UNNEST(JSON_QUERY_ARRAY(proj.fundings)) AS funding
# WHERE proj.id = rel.source AND
#   rel.target = 'openorgs____::759d59f05d77188faee99b7493b46805'
# GROUP BY funder
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                                          funder  total
# 0  Fundação para a Ciência e a Tecnologia, I.P.   3849
# 1         French National Research Agency (ANR)      6
# 2                           European Commission    302
# 3                    UK Research and Innovation      6

# %%
# %%bigquery
#
# SELECT EXTRACT(YEAR FROM DATE(startDate)) AS year,
#   REGEXP_EXTRACT(JSON_VALUE(funding.fundingStream.id), r'^[^:]*::([^:]*)') AS stream,
#   COUNT (DISTINCT proj.id) AS totalCOUNT
# FROM oag_v9_0_1.projects AS proj,
#   oag_v9_0_1.relations AS rel,
#   UNNEST(JSON_QUERY_ARRAY(proj.fundings)) AS funding
# WHERE proj.id = rel.source AND
#   rel.target = 'openorgs____::759d59f05d77188faee99b7493b46805' AND
#   JSON_VALUE(funding.jurisdiction) = 'EU'
# GROUP BY year, stream
# ORDER BY year DESC
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     year    stream  totalCOUNT
# 0   2025        HE          10
# 1   2024        HE          16
# 2   2023        HE          10
# 3   2022        HE          10
# 4   2022     H2020           4
# 5   2021     H2020          15
# 6   2020     H2020          12
# 7   2019     H2020           7
# 8   2018     H2020          13
# 9   2017     H2020          15
# 10  2016     H2020          13
# 11  2015     H2020          13
# 12  2014       FP7           5
# 13  2014     H2020           2
# 14  2013       FP7           6
# 15  2012       FP7          13
# 16  2011       FP7          14
# 17  2010       FP7          10
# 18  2009       FP7          12
# 19  2008       FP7           6
# 20  2007       FP7           1
# 21  <NA>  ERASMUS+          94
# 22  <NA>        HE           1
